# %% [markdown]
# 1 - Você recebeu um desafio de um colega do BIA que te perguntou como poderia criar uma caça palavras em python, contendo no mínimo 3 palavras imputadas pelo usuário.
#
# Você dele ler um conjunto de palavras e gerar um caça palavras.
#
# Um colega do BIA de 2020 te enviou um código, para ajudá-lo. (valor 2.0)
#
# A) Explique os algoritmos que o seu colega te apresentou
#
# B) Desenvolva a sua solução e explique

# %%
def main(): #criar uma função chamada main 
    s = "programacao" #variavel s recebe uma string 
    f = "aprovado" #variavel f recebe uma string 
    c = input('Entre com a letra para a alocação: ') #variavel c que será usada para alocar outra palavra
# quantas letras existem e em que posições? (~COMENTARIO DO EXERCICIO~)
    lst = [] #cria uma lista
    for pos,char in enumerate(s): #'pos' recebe a posição do caracter e o 'char' é o caracter daquela posição.
        if(char == c): #se o caracter for igual a letra de alocação escolhida pelo usuario...
            lst.append(pos) #adicione a posição do caracter na lista de posições
    print("posições onde foi encontrada a letra 'a'",lst) #mostrar onde foi encontrada a letra a e mostrar a lista
#vamos imprimir a letra usando a posicao 2 da lista (~COMENTARIO DO EXERCICIO~)
    lposi = lst[1] # a variavel 'lposi' recebe a posição que foi encontrado o segundo caracter na lista.
    x = 0
    for l in s:
        if x == lposi: #Se o x for igual a posição do segundo caracter encontrado na lista...
            print(f) #mostre 'aprovado'
        else: #Senão...
            print(l) #mostre o caracter referente ao valor de x da palavra programação...
        x+=1 #e adicione +1 no valor de x
        
# main()  , não irei executar o codigo acima pois irei criar o meu proprio, partindo de algumas coisas que possuem nesse, sendo tudo que está acima é a parte A, que é comentar o codigo do individuo.

# %%
#MEU CODIGO:

#Linhas do codigo a seguir que são iguais ao da def main(), não serão comentadas / explicadas novamente. 

from random import randint #Importando a ferramente randint da biblioteca random para ajudar na geração de caracteres aleatorios do caça palavra.
s = "programacao"
s = list(s) #transformando a variavel s em uma lista de caracteres da palavra programação, onde cada indice é uma letra da palavra.
f = "aprovado"
c = f[0] #variavel c recebe o caracter da posicao 0 da palavra aprovado, no caso 'a'
lista = []
for posicao, caracter in enumerate(s):
    if caracter == c:
        lista.append(posicao)
print("posições onde foi encontrada a letra 'a'", lista)

# vamos imprimir a letra a na posicao 2 da lista
posicao_lista = lista[1] #lposi recebe a posicao da segunda letra "a" da lista.
s[posicao_lista] = f #O caracter 'a' da lista S recebe a palavra / string "aprovado"
for letra in s: #para cada letra na lista s ....
    print(letra) #mostre a letra
maior = f #Serve para definir a quantidade de colunas que vai ter
while True: #criar um laço de repeticao
    f = str(input("Insira qual palavra você quer adicionar: ")) #pedir a palavra ao usuario e atribuir a var f
    c = f[0]  # Primeira letra 'a' de aprovado
    lista = [] #gerar uma lista
    
    for posicao, caracter in enumerate(s): #parte comentada no codigo princiapal...
        if caracter == c:
            lista.append(posicao)
    print(f"novas posições onde foi encontra a letra '{f[0]}'", lista) 

      
    if len(lista) == 0: #imprimir a letra "a" na posicao 2 da lista
        s.append(f)
    else:
        posicao_lista = lista[randint(0, len(lista) - 1)] #gerar aleatoriamente numero para preencher
        x = 0
        s[posicao_lista] = f
    for letra in s: #para cada letra da lista...
        print(letra) #mostre letra
    if len(f) > len(maior): #verificar qual palavra é maior (maior numero de colunas)
        maior = f
    if str(input("Continuar? [Ss] / [Nn] ")) in 'Nn': #perguntar ao usuario se ele deseja inserir outra palavra.
        break

for letra in s: #O codigo abaixo serve para preencher todo o resto com letras aleatorias
    if len(letra) == len(maior):
        for i in letra:
            print(i, end = ' ') #end='' é um argumento da função print() que contém uma string a ser inserida ao final da linha.
    else:
        for c in range(len(maior) - len(letra)):
            letra += chr(randint(ord('a'), ord('z'))) #de A até Z
        for i in letra:
            print(i, end = ' ')
    print()
# Out:
# posições onde foi encontrada a letra 'a' [5, 7, 9]
# p
# r
# o
# g
# r
# a
# m
# aprovado
# c
# a
# o
# Insira qual palavra você quer adicionar: teste
# novas posições onde foi encontra a letra 't' []
# p
# r
# o
# g
# r
# a
# m
# aprovado
# c
# a
# o
# teste
# Continuar? [Ss] / [Nn] s
# Insira qual palavra você quer adicionar: forte
# novas posições onde foi encontra a letra 'f' []
# p
# r
# o
# g
# r
# a
# m
# aprovado
# c
# a
# o
# teste
# forte
# Continuar? [Ss] / [Nn] s
# Insira qual palavra você quer adicionar: cavalo
# novas posições onde foi encontra a letra 'c' [8]
# p
# r
# o
# g
# r
# a
# m
# aprovado
# cavalo
# a
# o
# teste
# forte
# Continuar? [Ss] / [Nn] n
# p n f g u l c u
# r c z f z q b a
# o c a o h f o c
# g x y t g y c g
# r q q b q d z d
# a d s k g e t t
# m t d y c v z q
# a p r o v a d o
# c a v a l o x q
# a b u j t h n o
# o t w c r j n s
# t e s t e d i l
# f o r t e h n f
